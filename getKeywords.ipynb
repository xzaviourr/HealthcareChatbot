# %%
import pandas as pd
import re
disease_df = pd.read_json('Data/disease_dataset_full.json')
disease_df.head()
# Out:
#                               name  \
# 0   Alveolar protein sedimentation
# 1                        pertussis
# 2                   Benzene poison
# 3                    Breathing gas
# 4  A lot of amniotic fluid suction
#
#                                                 desc  \
# 0  Alveolar protein sedimentation (PAP), also kno...
# 1  Balance cough (WhoopingCough) is an acute resp...
# 2  Benzene is an aromatic hydrocarbon compound ob...
# 3  Asthmatoidbronchitis, also known as asthma bro...
# 4  The fetus inhaled a large amount of amniotic f...
#
#                                             category  \
# 0  [Disease encyclopedia,  internal medicine,  re...
# 1   [Disease Encyclopedia,  Pediatrics,  Pediatrics]
# 2      [Disease encyclopedia,  emergency department]
# 3  [Disease encyclopedia,  internal medicine,  re...
# 4   [Disease Encyclopedia,  Pediatrics,  Pediatrics]
#
#                                              prevent  \
# 0  1. Avoid infection of branch bacillus, Kraft p...
# 1  1. Control the source of infection: in the pop...
# 2  For acute poisoning patients, you can immediat...
# 3  According to the above, it is necessary to pay...
# 4  The key to preventing the prevention of the fe...
#
#                                                cause  \
# 0  The cause is not clear, and it is speculated t...
# 1  (1) Causes of the disease\nPathogenic bacteria...
# 2  Poisoning, acute, chronic division caused by s...
# 3  Because of a variety of viruses and bacterial ...
# 4  Any factor leads to an intrauterine or marital...
#
#                                              symptom yibao_status  get_prob  \
# 0  [Purple,  chest pain,  difficulty breathing,  ...           no  0.00002%
# 1  [There is a tattoo,  spasm cough,  chest tight...           no      0.5%
# 2            [Nausea,  convulsions,  feel obstacles]           no    0.065%
# 3  [Shurpling wheezing,  wheezing,  cilia epithel...           no      3-5%
# 4  [Face blue purple,  difficulty breathing,  lip...           no    0.001%
#
#                    get_way                    acompany  ...  \
# 0               Infectious  [Multiple lung infections]  ...
# 1  Respiratory propagation     [Lungs are not allowed]  ...
# 2               Infectious                    [anemia]  ...
# 3               Infectious          [Bronchial Asthma]  ...
# 4               Infectious       [Respiratory failure]  ...
#
#                                           cost_money  \
# 0  According to different hospitals, the charging...
# 1  According to different hospitals, the charging...
# 2  According to different conditions, different h...
# 3  According to different hospitals, the charging...
# 4  According to different hospitals, the charging...
#
#                                                check  \
# 0  [Chest CT examination,  lung biopsy,  bronchos...
# 1  [Ear,  nose,  throat strontium bacterial cultu...
# 2  [Blood routine,  bone marrow icon analysis,  f...
# 3  [Lung inspection,  lung and pleuropia,  anti-g...
# 4  [Lung inspection,  chest perspective,  chest f...
#
#                                       recommand_drug  \
# 0                                                 []
# 1  [Amber ethyromycin sheet,  amber erythromycin ...
# 2  [Bremen,  Eleven Golden Pills,  injecting Brem...
# 3  [Citric acid spray threshold,  aminophyllium t...
# 4                                                 []
#
#                                          drug_detail  \
# 0                                                 []
# 1  [HP Senxianex inner lane (wearing a heart) Hun...
# 2  [Guilin South Pharmaceuticals (Bremen Terrier)...
# 3  [Shuyingbacona de Aeroside (Bugnade aerosol), ...
# 4                                                 []
#
#                                          common_drug  \
# 0                                                 []
# 1  [Wearing the inner lactone tablets,  the neopl...
# 2                [Bremen Teni,  Eleven Golden Pills]
# 3       [Budnide aerosol,  spraywood chloride syrup]
# 4                                                 []
#
#                                               do_eat  \
# 0                                                 []
# 1  [Pumpkin seed kernel,  cabbage,  cherry tomato...
# 2          [Egg,  soy,  pork (thin),  cherry tomato]
# 3                        [Egg,  sea,  red,  cabbage]
# 4                                                 []
#
#                                              not_eat  \
# 0                                                 []
# 1              [Crab,  sea crab,  sea prawn,  conch]
# 2  [Sea crab,  sea shrimp,  sea cucumber (water i...
# 3  [Sea crab,  sea prawn,  conch,  pork (fat and ...
# 4                                                 []
#
#                                        recommand_eat  \
# 0                                                 []
# 1  [Steamed egg tarts,  lily double ear egg tarts...
# 2  [Dried bean fried leeks,  vegetarian white veg...
# 3  [Purosus porridge,  chrysanthemum reed root te...
# 4                                                 []
#
#                                             easy_get id
# 0                                               None  1
# 1                                 More than children  2
# 2  More common in shoes workers and workers who c...  3
# 3                                  No specific group  4
# 4                                   Send to newborns  5
#
# [5 rows x 24 columns]

# %%
import yake
kw_extractor = yake.KeywordExtractor()
#text = """spaCy is an open-source software library for advanced natural language processing, written in the programming languages Python and Cython. The library is published under the MIT license and its main developers are Matthew Honnibal and Ines Montani, the founders of the software company Explosion."""
language = "en"
max_ngram_size = 3
deduplication_threshold = 0.9
numOfKeywords = 20
custom_kw_extractor = yake.KeywordExtractor(lan=language, n=max_ngram_size, dedupLim=deduplication_threshold, top=numOfKeywords, features=None)

# %%
word=[]
for text in disease_df['prevent']:
    keywords = custom_kw_extractor.extract_keywords(text)
    word.append(keywords)
    # for kw in keywords:
    #     print(kw)

# %%
import spacy
nlp = spacy.load("en_core_sci_lg")
words_spacy=[]
for text in disease_df['prevent']:
    doc = nlp(text)
    print(doc.ents)
    words_spacy.append(doc.ents)
    break
    # for kw in keywords:
    #     print(kw)
# Out:
# c:\Users\Siddhi\HealthcareChatbot\venv\lib\site-packages\spacy\util.py:841: UserWarning: [W094] Model 'en_core_sci_lg' (0.2.4) specifies an under-constrained spaCy version requirement: >=2.2.1. This can lead to compatibility problems with older versions, or as new spaCy versions are released, because the model may say it's compatible when it's not. Consider changing the "spacy_version" in your meta.json to a version range, with a lower and upper pin. For example: >=3.2.0,<3.3.0
#   warnings.warn(warn_msg)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# c:\Users\Siddhi\HealthcareChatbot\getKeywords.ipynb Cell 6' in <module>
#       <a href='vscode-notebook-cell:/c%3A/Users/Siddhi/HealthcareChatbot/getKeywords.ipynb#ch0000005?line=0'>1</a> import spacy
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Siddhi/HealthcareChatbot/getKeywords.ipynb#ch0000005?line=1'>2</a> nlp = spacy.load("en_core_sci_lg")
#       <a href='vscode-notebook-cell:/c%3A/Users/Siddhi/HealthcareChatbot/getKeywords.ipynb#ch0000005?line=2'>3</a> words_spacy=[]
#       <a href='vscode-notebook-cell:/c%3A/Users/Siddhi/HealthcareChatbot/getKeywords.ipynb#ch0000005?line=3'>4</a> for text in disease_df['prevent']:
#
# File c:\Users\Siddhi\HealthcareChatbot\venv\lib\site-packages\spacy\__init__.py:51, in load(name, vocab, disable, exclude, config)
#      <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/__init__.py?line=29'>30</a> def load(
#      <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/__init__.py?line=30'>31</a>     name: Union[str, Path],
#      <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/__init__.py?line=31'>32</a>     *,
#    (...)
#      <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/__init__.py?line=35'>36</a>     config: Union[Dict[str, Any], Config] = util.SimpleFrozenDict(),
#      <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/__init__.py?line=36'>37</a> ) -> Language:
#      <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/__init__.py?line=37'>38</a>     """Load a spaCy model from an installed package or a local path.
#      <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/__init__.py?line=38'>39</a>
#      <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/__init__.py?line=39'>40</a>     name (str): Package name or model path.
#    (...)
#      <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/__init__.py?line=48'>49</a>     RETURNS (Language): The loaded nlp object.
#      <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/__init__.py?line=49'>50</a>     """
# ---> <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/__init__.py?line=50'>51</a>     return util.load_model(
#      <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/__init__.py?line=51'>52</a>         name, vocab=vocab, disable=disable, exclude=exclude, config=config
#      <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/__init__.py?line=52'>53</a>     )
#
# File c:\Users\Siddhi\HealthcareChatbot\venv\lib\site-packages\spacy\util.py:420, in load_model(name, vocab, disable, exclude, config)
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=417'>418</a>     return get_lang_class(name.replace("blank:", ""))()
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=418'>419</a> if is_package(name):  # installed as package
# --> <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=419'>420</a>     return load_model_from_package(name, **kwargs)  # type: ignore[arg-type]
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=420'>421</a> if Path(name).exists():  # path to model data directory
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=421'>422</a>     return load_model_from_path(Path(name), **kwargs)  # type: ignore[arg-type]
#
# File c:\Users\Siddhi\HealthcareChatbot\venv\lib\site-packages\spacy\util.py:453, in load_model_from_package(name, vocab, disable, exclude, config)
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=437'>438</a> """Load a model from an installed package.
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=438'>439</a>
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=439'>440</a> name (str): The package name.
#    (...)
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=449'>450</a> RETURNS (Language): The loaded nlp object.
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=450'>451</a> """
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=451'>452</a> cls = importlib.import_module(name)
# --> <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=452'>453</a> return cls.load(vocab=vocab, disable=disable, exclude=exclude, config=config)
#
# File c:\Users\Siddhi\HealthcareChatbot\venv\lib\site-packages\en_core_sci_lg\__init__.py:10, in load(**overrides)
#       <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/en_core_sci_lg/__init__.py?line=8'>9</a> def load(**overrides):
# ---> <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/en_core_sci_lg/__init__.py?line=9'>10</a>     nlp = load_model_from_init_py(__file__, **overrides)
#      <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/en_core_sci_lg/__init__.py?line=10'>11</a>     return nlp
#
# File c:\Users\Siddhi\HealthcareChatbot\venv\lib\site-packages\spacy\util.py:615, in load_model_from_init_py(init_file, vocab, disable, exclude, config)
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=612'>613</a> if not model_path.exists():
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=613'>614</a>     raise IOError(Errors.E052.format(path=data_path))
# --> <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=614'>615</a> return load_model_from_path(
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=615'>616</a>     data_path,
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=616'>617</a>     vocab=vocab,
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=617'>618</a>     meta=meta,
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=618'>619</a>     disable=disable,
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=619'>620</a>     exclude=exclude,
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=620'>621</a>     config=config,
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=621'>622</a> )
#
# File c:\Users\Siddhi\HealthcareChatbot\venv\lib\site-packages\spacy\util.py:487, in load_model_from_path(model_path, meta, vocab, disable, exclude, config)
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=484'>485</a> config_path = model_path / "config.cfg"
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=485'>486</a> overrides = dict_to_dot(config)
# --> <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=486'>487</a> config = load_config(config_path, overrides=overrides)
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=487'>488</a> nlp = load_model_from_config(config, vocab=vocab, disable=disable, exclude=exclude)
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=488'>489</a> return nlp.from_disk(model_path, exclude=exclude, overrides=overrides)
#
# File c:\Users\Siddhi\HealthcareChatbot\venv\lib\site-packages\spacy\util.py:646, in load_config(path, overrides, interpolate)
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=643'>644</a> else:
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=644'>645</a>     if not config_path or not config_path.exists() or not config_path.is_file():
# --> <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=645'>646</a>         raise IOError(Errors.E053.format(path=config_path, name="config.cfg"))
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=646'>647</a>     return config.from_disk(
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=647'>648</a>         config_path, overrides=overrides, interpolate=interpolate
#     <a href='file:///c%3A/Users/Siddhi/HealthcareChatbot/venv/lib/site-packages/spacy/util.py?line=648'>649</a>     )
#
# OSError: [E053] Could not read config.cfg from c:\Users\Siddhi\HealthcareChatbot\venv\lib\site-packages\en_core_sci_lg\en_core_sci_lg-0.2.4\config.cfg

# %%
# !python -m spacy validate
# Out:
# ⠙ Loading compatibility table...
# ✔ Loaded compatibility table
#
# ================= Installed pipeline packages (spaCy v3.2.0) =================
# ℹ spaCy installation:
# c:\Users\Siddhi\HealthcareChatbot\venv\lib\site-packages\spacy
#
# NAME             SPACY            VERSION
# en_core_web_sm   >=3.2.0,<3.3.0   3.2.0     ✔
